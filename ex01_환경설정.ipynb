# %% [markdown]
# <a href="https://colab.research.google.com/github/fsclass-n/big0611/blob/main/ex01_%ED%99%98%EA%B2%BD%EC%84%A4%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 코드 작성 후
# 실행 버튼을 클릭하여 실행
# 또는 shift+enter를 함께 눌러서 실행
print('Hello Machine Learning!')
# Out:
# Hello Machine Learning!

# %%
5+3
# Out:
# 8

# %% [markdown]
# # 1. 텍스트 모드
# ##(1) 텍스트 작성하기
# 주피터 노트북은 텍스트도 작성이 가능합니다.
#
# ##(2) 이미지 추가하기
# <p><img alt="Colaboratory logo" src="/img/colab_favicon.ico"></p>
