# %%
# 모듈
# : 함수나 변수 또는 클래스를 모아 놓은 파이썬 파일(*.py)이다.
# 모듈 만들기
# mod1.py
# def add(a, b):
#     return a + b

# def sub(a, b): 
#     return a - b

# %%
# 모듈 불러오기
# import는 현재 디렉터리에 있는 파일이나 파이썬 라이브러리가 저장된 디렉터리에 있는 모듈만 불러올 수 있다.
# import 모듈_이름
import mod1

# mod1.py 파일에 있는 add 함수를 사용하려면 mod1.add처럼 모듈 이름 뒤에 도트 연산자(.)를 붙이고 함수 이름을 쓰면 된다.
# 모듈.함수
print(mod1.add(3, 4))
print(mod1.sub(4, 2))
# Out:
# 7
# 2

# %%
# 함수를 직접 import하면 모듈 이름을 붙이지 않고 바로 해당 모듈의 함수를 쓸 수 있다.
# from 모듈_이름 import 모듈_함수
from mod1 import add

# 함수
add(3, 4)
# Out:
# 7

# %%
# from 모듈_이름 import 모듈_함수1, 모듈_함수2
from mod1 import add, sub

from mod1 import *

# %%
# if __name__ == "__main__":의 의미
# mod1.py 파일을 실행할 경우, mod1.py의 __name__ 변수에는 __main__ 값이 저장된다. 하지만 파이썬 셸이나 다른 파이썬 모듈에서 mod1을 import할 경우에는 mod1.py의 __name__ 변수에 mod1.py의 모듈 이름인 mod1이 저장된다.

# %%
import mod1
mod1.__name__
# Out:
# 'mod1'

# %%
# mod2.py
# PI = 3.141592

# class Math: 
#     def solv(self, r): 
#         return PI * (r ** 2) 

# def add(a, b): 
#     return a+b

# %%
import mod2
print(mod2.PI)

a = mod2.Math()
print(a.solv(2))

print(mod2.add(mod2.PI, 4.4))
# Out:
# 3.141592
# 12.566368
# 7.5415920000000005

# %%
# 다른 파일에서 모듈 불러오기
import mod2
result = mod2.add(3, 4)
print(result)
# Out:
# 7

# %%
# 다른 디렉터리에 있는 모듈을 불러오는 방법
# 1. sys.path.append 사용하기
import sys
# sys 모듈을 사용하면 파이썬 라이브러리가 설치되어 있는 디렉터리를 확인할 수 있다.
sys.path
# Out:
# ['C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip',
#  'C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311\\DLLs',
#  'C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311\\Lib',
#  'C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311',
#  'e:\\wi\\git\\big0611\\.venv',
#  '',
#  'e:\\wi\\git\\big0611\\.venv\\Lib\\site-packages']

# %%
sys.path.append(r'E:\wi\git\big0611\py\p04_머신러닝\ch01_문법정리\mymod')

# %%
sys.path
# Out:
# ['C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip',
#  'C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311\\DLLs',
#  'C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311\\Lib',
#  'C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311',
#  'e:\\wi\\git\\big0611\\.venv',
#  '',
#  'e:\\wi\\git\\big0611\\.venv\\Lib\\site-packages',
#  'E:\\wi\\git\\big0611\\py\\p04_머신러닝\\ch01_문법정리\\mymod']

# %%
import mod2
print(mod2.add(3,4))
# Out:
# 7

# %%
# 2. PYTHONPATH 환경 변수 사용하기
# set PYTHONPATH=E:\wi\git\big0611\py\p04_머신러닝\ch01_문법정리\mymod
# %env PYTHONPATH=E:\wi\git\big0611\py\p04_머신러닝\ch01_문법정리\mymod
