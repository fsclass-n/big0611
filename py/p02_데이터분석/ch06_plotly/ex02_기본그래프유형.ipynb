# %% [markdown]
# # 기본 그래프 유형
# ## 선 그래프(line plot)

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
num = np.random.randn(30)
num
# Out:
# array([-0.85168307, -0.46518405, -0.30364592, -0.89480238,  0.74808401,
#        -1.02997796,  0.39474718,  0.67167863,  0.16550998, -1.41650256,
#         0.61275697, -1.02202599,  0.98043787, -1.36789967, -1.1357131 ,
#        -0.33289711,  1.70240173,  0.2901776 ,  1.40749933, -3.06297604,
#        -1.5682113 , -1.30047934,  1.44120454,  0.02372289, -0.28025482,
#         0.11991087, -2.11161248, -1.0059031 ,  0.70599128, -0.35001059])

# %%
# 시계열 데이터 생성
# 2024-01-01 부터 D(Daily) 하루씩 30일간
dates = pd.date_range('2026-06-01', periods=30, freq='D')
# np.random.randn(30): 평균 0, 표준편차 1에 따른 난수 30개
values = np.cumsum(np.random.randn(30)) + 100

time_series = pd.DataFrame({
    '날짜': dates,
    '주가': values
})
time_series
# Out:
#            날짜          주가
# 0  2026-06-01  100.435528
# 1  2026-06-02  102.560755
# 2  2026-06-03  103.231266
# 3  2026-06-04  103.750353
# 4  2026-06-05  102.449385
# 5  2026-06-06  102.669775
# 6  2026-06-07  102.240094
# 7  2026-06-08  101.959254
# 8  2026-06-09  102.492954
# 9  2026-06-10  102.098217
# 10 2026-06-11  102.510658
# 11 2026-06-12  101.638496
# 12 2026-06-13  100.474407
# 13 2026-06-14   99.907658
# 14 2026-06-15  101.086592
# 15 2026-06-16  100.910956
# 16 2026-06-17  100.781406
# 17 2026-06-18  100.120737
# 18 2026-06-19   99.801035
# 19 2026-06-20  101.007103
# 20 2026-06-21  101.822802
# 21 2026-06-22  101.595594
# 22 2026-06-23   99.869742
# 23 2026-06-24   98.892002
# 24 2026-06-25   99.007343
# 25 2026-06-26   99.687551
# 26 2026-06-27   97.476249
# 27 2026-06-28   95.964507
# 28 2026-06-29   95.628540
# 29 2026-06-30   95.507644

# %%
# 1. 단일 선 그래프
fig = px.line(
    time_series, 
    x='날짜', 
    y='주가',
    title='일일 주가 변동',
    markers="True"
)
fig.show()

# %%
num = np.cumsum(np.random.randn(1))[0]
print(num)
# 참고: 숫자 범위 제한 없다.
# Out:
# -0.10061600957736325

# %%
# 2. 다중 선 그래프
# 데이터 분석
companies = ['LG전자', '삼성전자', 'SK하이닉스']
stock_data = []

for company in companies:
    for i, date in enumerate(dates):
        price = 100 + np.cumsum(np.random.randn(1))[0] * (i + 1) / 10
        stock_data.append({
            '날짜': date,
            '회사': company,
            '주가': price
        })

df_stocks = pd.DataFrame(stock_data)
df_stocks
# Out:
#            날짜      회사          주가
# 0  2026-06-01    LG전자  100.156189
# 1  2026-06-02    LG전자  100.119281
# 2  2026-06-03    LG전자   99.826562
# 3  2026-06-04    LG전자   99.970015
# 4  2026-06-05    LG전자  100.140489
# ..        ...     ...         ...
# 85 2026-06-26  SK하이닉스  105.381604
# 86 2026-06-27  SK하이닉스  100.888263
# 87 2026-06-28  SK하이닉스   97.902420
# 88 2026-06-29  SK하이닉스   98.480408
# 89 2026-06-30  SK하이닉스  102.930243
#
# [90 rows x 3 columns]

# %%
# 데이터 시각화
fig = px.line(
    df_stocks,
    x='날짜', # x축 컬럼명
    y='주가', # y축 컬럼명
    color='회사', # 그룹별 색상
    title='회사별 주가 비교', # 그래프 제목
    line_dash='회사' # 선 스타일
)
fig.show()

# %% [markdown]
# ## 산점도(scatter plot)

# %%
# 1. 기본 산점도
# 키와 몸무게 데이터
height_weight = {
    '키': [160, 165, 170, 175, 180, 162, 168, 172, 178, 185],
    '몸무게': [55, 60, 65, 70, 75, 58, 63, 68, 73, 80],
    '성별': ['여성', '여성', '여성', '남성', '남성', '여성', '여성', '남성', '남성', '남성']
}

df_body = pd.DataFrame(height_weight)
df_body
# Out:
#      키  몸무게  성별
# 0  160   55  여성
# 1  165   60  여성
# 2  170   65  여성
# 3  175   70  남성
# 4  180   75  남성
# 5  162   58  여성
# 6  168   63  여성
# 7  172   68  남성
# 8  178   73  남성
# 9  185   80  남성
